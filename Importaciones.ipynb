# %% [markdown]
# Importaciones que llevamos

# %%
# para series, dataframes, random, nunique...
import numpy as np
import pandas as pd

# para expresiones regulares
import re

# para trabajar con fechas 
import datetime as dt

# para abrir archivos json
import json

# para abrir ficheros xml
import xml.etree.ElementTree as ET

# para usar sql
import sqlite3
Además otras librerías y módulos que te permiten acceso a otros gestores son:
* SQL Server: `pyodbc`
* Oracle: `cx_Oracle`
* PostgreSQL: `psycopg2`
